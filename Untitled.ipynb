# %%
import pandas as pd

# %%
quotes = pd.read_csv('quote_stash.csv')
quotes = quotes[['quote', 'author']]
quotes.head()
# Out:
#                                                quote             author
# 0        Pain is inevitable, but misery is optional.         Tim Hansel
# 1  To avoid criticism, do nothing, say nothing, b...     Elbert Hubbard
# 2  Believe and act as if it were impossible to fail.  Charles Kettering
# 3  Never get out of the boat. Absolutely goddamn ...    Captain Willard
# 4  Nobody can make you feel inferior without your...  Eleanor Roosevelt

# %%
quotes = quotes.drop_duplicates(subset='author', keep='last')
quotes
# Out:
#                                                  quote  \
# 0          Pain is inevitable, but misery is optional.
# 1    To avoid criticism, do nothing, say nothing, b...
# 2    Believe and act as if it were impossible to fail.
# 3    Never get out of the boat. Absolutely goddamn ...
# 4    Nobody can make you feel inferior without your...
# 5    What we fear doing most is usually what we mos...
# 6    Everything you’ve ever wanted is on the other ...
# 7    Success is going from failure to failure witho...
# 8       If there is no struggle, there is no progress.
# 9    There are no short cuts to any place worth going.
# 10   In each business, we have two strands: the day...
# 11   No person will have occasion to complain of th...
# 12   The most common form of despair is not being w...
# 13     There are no traffic jams along the extra mile.
# 14             Do it trembling if you must, but do it!
# 15   Money is, in some respects, like fire. It is a...
# 16   If you don't go after what you want, you'll ne...
# 17   And it is awfully hard to come up with those i...
# 18          You miss 100% of the shots you don’t take.
# 19   Every next level of your life will demand a di...
# 20   Every strike brings me closer to the next home...
# 21   Obsessed is just a word the lazy use to descri...
# 22   Be who you are and say what you feel, because ...
# 23     Change your thoughts and you change your world.
# 24     If you aren’t going all the way, why go at all?
# 25          The dreamers are the saviors of the world.
# 26   One thing modeling taught me is that the spotl...
# 27   It’s not whether you get knocked down, it’s wh...
# 28   Very often a change of self is needed more tha...
# 29   You must do what others don't to achieve what ...
# ..                                                 ...
# 78   It takes courage to grow up and become who you...
# 79   Keep your face to the sunshine and you can nev...
# 80   Look at everything always as though you were s...
# 81   Don’t downgrade your dream just to fit your re...
# 82   The trick is to enjoy life. Don't wish away yo...
# 83      Action is the foundational key to all success.
# 84   There is only one success: to be able to spend...
# 85      Life is beautiful, as long as it consumes you.
# 86                     Make each day your masterpiece.
# 87   Never let your memories be greater than your d...
# 88   Write it on your heart that every day is the b...
# 89   The best way to predict the future is to inven...
# 90   The best time to plant a tree was twenty years...
# 91   I think laziness is a cardinal sin -- not in t...
# 92         Do what you love and the money will follow.
# 93     Champions keep playing until they get it right.
# 94                 The best way out is always through.
# 95   Every morning, I imagine creating a new busine...
# 96   The highest profits are made in trades that sh...
# 97   Fact is, no one cares about your marketing goa...
# 98   It is much more difficult to judge oneself tha...
# 99   The first principle is that you must not fool ...
# 100          The best dreams happen when you’re awake.
# 101  Remember that sometimes not getting what you w...
# 102  I'm sure the universe is full of intelligent l...
# 103   Don’t wish it were easier, wish you were better.
# 104  Out yonder there was this huge world, which ex...
# 105  Life is beautiful, so long as it is consuming ...
# 106  I offer you peace. I offer you love. I offer y...
# 107  When we are mindful, deeply in touch with the ...
#
#                                                 author
# 0                                           Tim Hansel
# 1                                       Elbert Hubbard
# 2                                    Charles Kettering
# 3                                      Captain Willard
# 4                                    Eleanor Roosevelt
# 5                                          Tim Ferriss
# 6                                        George Addair
# 7                                    Winston Churchill
# 8                                   Frederick Douglass
# 9                                        Beverly Sills
# 10                                       Martin Reeves
# 11                                    Thomas Jefferson
# 12                                       Kurt Vonnegut
# 13                                      Roger Staubach
# 14                                           Emmet Fox
# 15                                        P. T. Barnum
# 16                                        Nora Roberts
# 17                                       Paul B. Brown
# 18                                       Wayne Gretzky
# 19                                             Unknown
# 20                                           Babe Ruth
# 21                                      Russell Warren
# 22                                   Bernard M. Baruch
# 23                                Norman Vincent Peale
# 24                                          Joe Namath
# 25                                         James Allen
# 26                                         Liya Kebede
# 27                                      Vince Lombardi
# 28                           Arthur Christopher Benson
# 29                                           Les Brown
# ..                                                 ...
# 78                                       E.E. Cummings
# 79                                        Helen Keller
# 80                                         Betty Smith
# 81                                        Stuart Scott
# 82                               Marjorie Pay Hinckley
# 83                                       Pablo Picasso
# 84                                  Christopher Morley
# 85                                            Socrates
# 86                                         John Wooden
# 87                                        Doug Ivester
# 88                                 Ralph Waldo Emerson
# 89                                            Alan Kay
# 90                                     Chinese Proverb
# 91                                    François Chollet
# 92                                      Marsha Sinetar
# 93                                    Billie Jean King
# 94                                        Robert Frost
# 95   Manuel Amuantegui, Finding Motivation in Unusu...
# 96                                     Jesse Livermore
# 97                                          Shane Snow
# 98                            Antoine de Saint-Exupéry
# 99                                     Richard Feynman
# 100                                 Cherie Gilderbloom
# 101                                         Dalai Lama
# 102                                   Arthur C. Clarke
# 103                                           Jim Rohn
# 104                                    Albert Einstein
# 105                                      D.H. Lawrence
# 106                                     Mahatma Gandhi
# 107                                    Thich Nhat Hanh
#
# [108 rows x 2 columns]

# %%
# pip install nltk
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/chandani/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

all_compounds = []
for sentence in quotes['quote']:
    print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
        print()
        if k == 'compound':
            all_compounds.append(ss[k])
# Out:
# Pain is inevitable, but misery is optional.
# compound: -0.802,
# neg: 0.59,
# neu: 0.41,
# pos: 0.0,
# To avoid criticism, do nothing, say nothing, be nothing.
# compound: -0.6249,
# neg: 0.421,
# neu: 0.579,
# pos: 0.0,
# Believe and act as if it were impossible to fail.
# compound: -0.5423,
# neg: 0.28,
# neu: 0.72,
# pos: 0.0,
# Never get out of the boat. Absolutely goddamn right. Unless you were goin' all the way.
# compound: -0.5256,
# neg: 0.184,
# neu: 0.816,
# pos: 0.0,
# Nobody can make you feel inferior without your consent.
# compound: -0.5213,
# neg: 0.384,
# neu: 0.616,
# pos: 0.0,
# What we fear doing most is usually what we most need to do.
# compound: -0.4939,
# neg: 0.211,
# neu: 0.789,
# pos: 0.0,
# Everything you’ve ever wanted is on the other side of fear.
# compound: -0.4939,
# neg: 0.242,
# neu: 0.758,
# pos: 0.0,
# Success is going from failure to failure without losing your enthusiasm.
# compound: -0.4805,
# neg: 0.431,
# neu: 0.287,
# pos: 0.282,
# If there is no struggle, there is no progress.
# compound: -0.4404,
# neg: 0.462,
# neu: 0.345,
# pos: 0.193,
# There are no short cuts to any place worth going.
# compound: -0.3612,
# neg: 0.331,
# neu: 0.526,
# pos: 0.143,
# In each business, we have two strands: the day-to-day, and the future group thinking, 'How do I disrupt myself?' The people running it can't be the same ones thinking about its disruption.
# compound: -0.3612,
# neg: 0.077,
# neu: 0.923,
# pos: 0.0,
# No person will have occasion to complain of the want of time who never loses any.
# compound: -0.3481,
# neg: 0.235,
# neu: 0.601,
# pos: 0.163,
# The most common form of despair is not being who you are.
# compound: -0.3182,
# neg: 0.173,
# neu: 0.827,
# pos: 0.0,
# There are no traffic jams along the extra mile.
# compound: -0.296,
# neg: 0.216,
# neu: 0.784,
# pos: 0.0,
# Do it trembling if you must, but do it!
# compound: -0.2598,
# neg: 0.203,
# neu: 0.797,
# pos: 0.0,
# Money is, in some respects, like fire. It is a very excellent servant, but a terrible master.
# compound: -0.2391,
# neg: 0.269,
# neu: 0.46,
# pos: 0.271,
# If you don't go after what you want, you'll never have it. If you don't ask, the answer is always no. If you don't step forward, you're always in the same place.
# compound: -0.2263,
# neg: 0.066,
# neu: 0.896,
# pos: 0.039,
# And it is awfully hard to come up with those ideas if you don't have any time to think.
# compound: -0.1761,
# neg: 0.086,
# neu: 0.914,
# pos: 0.0,
# You miss 100% of the shots you don’t take.
# compound: -0.1531,
# neg: 0.167,
# neu: 0.833,
# pos: 0.0,
# Every next level of your life will demand a different version of you.
# compound: -0.128,
# neg: 0.12,
# neu: 0.88,
# pos: 0.0,
# Every strike brings me closer to the next home run.
# compound: -0.128,
# neg: 0.143,
# neu: 0.857,
# pos: 0.0,
# Obsessed is just a word the lazy use to describe the dedicated.
# compound: -0.0516,
# neg: 0.276,
# neu: 0.526,
# pos: 0.197,
# Be who you are and say what you feel, because those who mind don't matter, and those who matter don't mind.
# compound: -0.0382,
# neg: 0.102,
# neu: 0.898,
# pos: 0.0,
# Change your thoughts and you change your world.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# If you aren’t going all the way, why go at all?
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# The dreamers are the saviors of the world.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# One thing modeling taught me is that the spotlight can change everything.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# It’s not whether you get knocked down, it’s whether you get up.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Very often a change of self is needed more than a change of scene.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# You must do what others don't to achieve what others won't.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# I don't know who my grandfather was; I am much more concerned to know what his grandson will be.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# If you have everything under control, you’re not moving fast enough.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# You've got to bumble forward into the unknown.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# How Everyone you Will Ever Meet Knows Something that You Don't.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Don’t wait. The time will never be just right.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Learn from yesterday, live for today, look to tomorrow, rest this afternoon.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# The power of imagination makes us infinite.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Forever is composed of nows.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Don’t count the days, make the days count.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Always make a total effort, even when the odds are against you.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# If you can’t outplay them, outwork them.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# When you come to a roadblock, take a detour.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Believe you can and you’re halfway there.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Do what you can, where you are, with what you have.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Even if you’re on the right track, you’ll get run over if you just sit there.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Life is 10% what happens to you and 90% how you react to it.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Life's simple. You make choices and you don't look back.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Light tomorrow with today.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# I will go anywhere as long as it is forward.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# The difference between ordinary and extraordinary is that little extra.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# Don't live the same day over and over again and call that a life.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# When you talk, you are only repeating what you already know. But if you listen, you may learn something new.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# If you have some power, then your job is to empower somebody else.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# It is never too late to be what you might have been.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# The price of anything is the amount of life you exchange for it.
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# It does not do to leave a live dragon out of your calculations, if you live near him.
# compound: 0.0382,
# neg: 0.0,
# neu: 0.933,
# pos: 0.067,
# Tough times never last, but tough people do.
# compound: 0.0785,
# neg: 0.142,
# neu: 0.681,
# pos: 0.177,
# The more I want to get something done, the less I call it work.
# compound: 0.1513,
# neg: 0.0,
# neu: 0.874,
# pos: 0.126,
# A person who is nice to you, but rude to the waiter, is not a nice person.
# compound: 0.1531,
# neg: 0.185,
# neu: 0.556,
# pos: 0.259,
# It does not matter how slowly you go as long as you do not stop.
# compound: 0.2057,
# neg: 0.067,
# neu: 0.814,
# pos: 0.118,
# Try not. Do, or do not. There is no try.
# compound: 0.2235,
# neg: 0.0,
# neu: 0.827,
# pos: 0.173,
# Our dreams feel real while we're in them. It's only when we wake we realize things were strange
# compound: 0.2263,
# neg: 0.088,
# neu: 0.78,
# pos: 0.132,
# The gateway skill to good time management is when you ask not just what you need to do, but how long it will take.
# compound: 0.2382,
# neg: 0.0,
# neu: 0.922,
# pos: 0.078,
# Life is not a problem to be solved, but a reality to be experienced.
# compound: 0.2912,
# neg: 0.0,
# neu: 0.759,
# pos: 0.241,
# Every moment is a fresh beginning.
# compound: 0.3182,
# neg: 0.0,
# neu: 0.635,
# pos: 0.365,
# Waking up this morning, I smile. 24 brand new hours are before me. I vow to live fully in each moment.
# compound: 0.3612,
# neg: 0.0,
# neu: 0.878,
# pos: 0.122,
# Sell a man a fish, he eats for a day. Teach a man how to fish, you ruin a wonderful business opportunity.
# compound: 0.4019,
# neg: 0.156,
# neu: 0.576,
# pos: 0.267,
# You must be the change you wish to see in the world.
# compound: 0.4019,
# neg: 0.0,
# neu: 0.803,
# pos: 0.197,
# A year from now you may wish you had started today.
# compound: 0.4019,
# neg: 0.0,
# neu: 0.769,
# pos: 0.231,
# If you don’t build your dreams, someone will hire you to build theirs.
# compound: 0.4019,
# neg: 0.0,
# neu: 0.816,
# pos: 0.184,
# You must be the person you have never had the courage to be. Gradually, you will discover that you are that person, but until you can see this clearly, you must pretend and invent.
# compound: 0.4163,
# neg: 0.088,
# neu: 0.803,
# pos: 0.108,
# The road to Easy Street goes through the sewer.
# compound: 0.4404,
# neg: 0.0,
# neu: 0.734,
# pos: 0.266,
# The harder I work, the luckier I get.
# compound: 0.4404,
# neg: 0.0,
# neu: 0.633,
# pos: 0.367,
# Just keep going. Everybody gets better if they keep at it.
# compound: 0.4404,
# neg: 0.0,
# neu: 0.775,
# pos: 0.225,
# 'What day is it?' asked Pooh. 'It’s today,' squeaked Piglet. 'My favorite day,' said Pooh.
# compound: 0.4588,
# neg: 0.0,
# neu: 0.824,
# pos: 0.176,
# The competitor to be feared is one who never bothers about you at all, but goes on making his own business better all the time.
# compound: 0.4671,
# neg: 0.072,
# neu: 0.752,
# pos: 0.176,
# People love to buy, they don't like to be sold.
# compound: 0.4749,
# neg: 0.147,
# neu: 0.559,
# pos: 0.294,
# Few "great" ideas come from an individual; instead, they’re gradually expanded on and improved by a team or network of individuals.
# compound: 0.4767,
# neg: 0.0,
# neu: 0.86,
# pos: 0.14,
# It takes courage to grow up and become who you really are.
# compound: 0.4939,
# neg: 0.0,
# neu: 0.775,
# pos: 0.225,
# Keep your face to the sunshine and you can never see the shadow.
# compound: 0.4939,
# neg: 0.0,
# neu: 0.789,
# pos: 0.211,
# Look at everything always as though you were seeing it either for the first or last time: Thus is your time on earth filled with glory.
# compound: 0.5423,
# neg: 0.0,
# neu: 0.877,
# pos: 0.123,
# Don’t downgrade your dream just to fit your reality.
# compound: 0.5423,
# neg: 0.0,
# neu: 0.609,
# pos: 0.391,
# The trick is to enjoy life. Don't wish away your days, waiting for better ones ahead.
# compound: 0.5635,
# neg: 0.16,
# neu: 0.557,
# pos: 0.283,
# Action is the foundational key to all success.
# compound: 0.5719,
# neg: 0.0,
# neu: 0.654,
# pos: 0.346,
# There is only one success: to be able to spend your life in your own way.
# compound: 0.5719,
# neg: 0.0,
# neu: 0.802,
# pos: 0.198,
# Life is beautiful, as long as it consumes you.
# compound: 0.5994,
# neg: 0.0,
# neu: 0.672,
# pos: 0.328,
# Make each day your masterpiece.
# compound: 0.6249,
# neg: 0.0,
# neu: 0.494,
# pos: 0.506,
# Never let your memories be greater than your dreams.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.574,
# pos: 0.426,
# Write it on your heart that every day is the best day in the year.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.769,
# pos: 0.231,
# The best way to predict the future is to invent it.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.704,
# pos: 0.296,
# The best time to plant a tree was twenty years ago, the second-best time is right now.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.781,
# pos: 0.219,
# I think laziness is a cardinal sin -- not in the sense that you should always keep busy, but in the sense that if you have the potential to create something that can be useful to others, then you should do everything you can to make it happen.
# compound: 0.6369,
# neg: 0.044,
# neu: 0.83,
# pos: 0.125,
# Do what you love and the money will follow.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.656,
# pos: 0.344,
# Champions keep playing until they get it right.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.536,
# pos: 0.464,
# The best way out is always through.
# compound: 0.6369,
# neg: 0.0,
# neu: 0.588,
# pos: 0.412,
# Every morning, I imagine creating a new business that needs to be sold by the end of the day. I better hustle today!
# compound: 0.6588,
# neg: 0.0,
# neu: 0.769,
# pos: 0.231,
# The highest profits are made in trades that show a profit right from the start.
# compound: 0.7003,
# neg: 0.0,
# neu: 0.674,
# pos: 0.326,
# Fact is, no one cares about your marketing goals. But everyone likes a good story.
# compound: 0.7579,
# neg: 0.105,
# neu: 0.478,
# pos: 0.416,
# It is much more difficult to judge oneself than to judge others. If you succeed in judging yourself rightly, then you are indeed a man of true wisdom.
# compound: 0.7655,
# neg: 0.079,
# neu: 0.654,
# pos: 0.267,
# The first principle is that you must not fool yourself and you are the easiest person to fool.
# compound: 0.7658,
# neg: 0.0,
# neu: 0.663,
# pos: 0.337,
# The best dreams happen when you’re awake.
# compound: 0.7845,
# neg: 0.0,
# neu: 0.42,
# pos: 0.58,
# Remember that sometimes not getting what you want is a wonderful stroke of luck.
# compound: 0.7906,
# neg: 0.0,
# neu: 0.556,
# pos: 0.444,
# I'm sure the universe is full of intelligent life. It's just been too intelligent to come here.
# compound: 0.8074,
# neg: 0.0,
# neu: 0.628,
# pos: 0.372,
# Don’t wish it were easier, wish you were better.
# compound: 0.8779,
# neg: 0.0,
# neu: 0.311,
# pos: 0.689,
# Out yonder there was this huge world, which exists independently of us human beings and which stands before us like a great, eternal riddle, at least partially accessible to our inspection and thinking. The contemplation of this world beckoned like a liberation…
# compound: 0.8939,
# neg: 0.0,
# neu: 0.754,
# pos: 0.246,
# Life is beautiful, so long as it is consuming you. When it is rushing through you, destroying you, life is glorious. It is best to roar away, like a fire with a great draught, white-hot to the last bit.
# compound: 0.9313,
# neg: 0.109,
# neu: 0.546,
# pos: 0.344,
# I offer you peace. I offer you love. I offer you friendship. I see your beauty. I hear your need. I feel your feelings.
# compound: 0.9371,
# neg: 0.0,
# neu: 0.493,
# pos: 0.507,
# When we are mindful, deeply in touch with the present moment, our understanding of what is going on deepens, and we begin to be filled with acceptance, joy, peace and love.
# compound: 0.9382,
# neg: 0.0,
# neu: 0.651,
# pos: 0.349,

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.plot(sorted(all_compounds))
plt.title('Overall sentiment in quote stash')
plt.grid()

# %%
quotes['sentiment_score'] = all_compounds
quotes.head()
# Out:
#                                                quote             author  \
# 0        Pain is inevitable, but misery is optional.         Tim Hansel
# 1  To avoid criticism, do nothing, say nothing, b...     Elbert Hubbard
# 2  Believe and act as if it were impossible to fail.  Charles Kettering
# 3  Never get out of the boat. Absolutely goddamn ...    Captain Willard
# 4  Nobody can make you feel inferior without your...  Eleanor Roosevelt
#
#    sentiment_score
# 0          -0.8020
# 1          -0.6249
# 2          -0.5423
# 3          -0.5256
# 4          -0.5213

# %%
import numpy as np

# the most negative
np.min(quotes['sentiment_score'])

# the most positive
np.max(quotes['sentiment_score'])

# the most negative
quotes[quotes['sentiment_score'] == np.min(quotes['sentiment_score']) ]

# the most positive
quotes[quotes['sentiment_score'] == np.max(quotes['sentiment_score']) ]
# Out:
#                                                  quote           author  \
# 107  When we are mindful, deeply in touch with the ...  Thich Nhat Hanh
#
#      sentiment_score
# 107           0.9382

# %%
import pandas as pd
import numpy as np
from random import randrange

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# declare global variable
quotes = None

def prepare_sentiment_quote_stash(quote_stash_path):
    global quotes
    
    # load the quote stash
    quotes = pd.read_csv(quote_stash_path)
    
    sid = SentimentIntensityAnalyzer()
    
    all_compounds = []
    for sentence in quotes['quote']:
        ss = sid.polarity_scores(sentence)
        for k in sorted(ss):
            if k == 'compound':
                all_compounds.append(ss[k])
                
    
    # add sentiment to the data
    quotes['sentiment_score'] = all_compounds
    
    # create ladder index
    quotes = quotes.sort_values('sentiment_score')
    quotes['index'] = [ix for ix in range(0, len(quotes))] 
    
    return quotes
     
    
    
    
prepare_sentiment_quote_stash('quote_stash.csv')
quotes.head()
# Out:
#                                                quote             author  \
# 0        Pain is inevitable, but misery is optional.         Tim Hansel
# 1  To avoid criticism, do nothing, say nothing, b...     Elbert Hubbard
# 2  Believe and act as if it were impossible to fail.  Charles Kettering
# 3  Never get out of the boat. Absolutely goddamn ...    Captain Willard
# 4  Nobody can make you feel inferior without your...  Eleanor Roosevelt
#
#    sentiment_score  index
# 0          -0.8020      0
# 1          -0.6249      1
# 2          -0.5423      2
# 3          -0.5256      3
# 4          -0.5213      4

# %%
max_index_value = np.max(quotes['index'].values)

def gimme_a_quote_index(direction = None, current_index = None):
    rand_index = randrange(max_index_value)
    darker = None
    brighter = None
    
    
    # New session visit
    if current_index is None:
        brighter = rand_index
        
    if direction == 'brighter':
        brighter = current_index
    else:
        darker = current_index
         
    if darker is not None:
        current_index = rand_index

        try:
            current_index = int(darker)
        except ValueError:
            # somebody is gaming the system
            current_index = rand_index

            
        if current_index > 0:
            # try for a lesser value than current one
            rand_index = randrange(0, current_index)
            print('darker')
        else:
            # already at lowest point so assign a new random of full set
            rand_index = rand_index


    elif brighter is not None:

        try:
            current_index = int(brighter)
        except ValueError:
            # somebody is gaming the system
            current_index = rand_index

        # try for a higher value than current one
        if current_index < max_index_value -1:
            rand_index = randrange(current_index, max_index_value)
            print('brighter')
        else:
            # already at highest point so assign a new random of full set
            rand_index = rand_index

    else:
        # grab a random value
        rand_index = rand_index
        
    return (rand_index)
        


quotes[quotes['index'] == gimme_a_quote_index('brighter', 20)   ]
# Out:
# brighter
#                                                  quote           author  \
# 104  Out yonder there was this huge world, which ex...  Albert Einstein
#
#      sentiment_score  index
# 104           0.8939    104
